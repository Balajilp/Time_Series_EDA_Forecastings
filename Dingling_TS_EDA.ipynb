# %% [markdown]
# <a href="https://colab.research.google.com/github/Balajilp/Time_Series_EDA_Forecastings/blob/main/Dingling_TS_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install download

# %%
# Integrating google drive with google colab
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import seaborn as sns

import matplotlib as mpl 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

from datetime import datetime

mpl.rcParams['figure.figsize']=(8, 6)
mpl.rcParams['axes.grid']=False

# %%
# Loading the Dingling Dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataSet/PRSA_Data_Dingling_20130301-20170228.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#           No  year  month  day  hour  ...  DEWP  RAIN   wd  WSPM   station
# 0          1  2013      3    1     0  ... -19.7   0.0    E   0.5  Dingling
# 1          2  2013      3    1     1  ... -19.0   0.0  ENE   0.7  Dingling
# 2          3  2013      3    1     2  ... -19.9   0.0  ENE   0.2  Dingling
# 3          4  2013      3    1     3  ... -19.1   0.0  NNE   1.0  Dingling
# 4          5  2013      3    1     4  ... -19.4   0.0    N   2.1  Dingling
# ...      ...   ...    ...  ...   ...  ...   ...   ...  ...   ...       ...
# 35059  35060  2017      2   28    19  ... -13.3   0.0  NNE   1.3  Dingling
# 35060  35061  2017      2   28    20  ... -14.0   0.0    N   2.1  Dingling
# 35061  35062  2017      2   28    21  ... -13.0   0.0    N   1.5  Dingling
# 35062  35063  2017      2   28    22  ... -12.6   0.0   NW   1.4  Dingling
# 35063  35064  2017      2   28    23  ... -12.2   0.0    N   1.9  Dingling
#
# [35064 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
# we need to combine this all year date month hour for that we are creating function
def convert_datetime(x):
  return datetime.strptime(x, "%Y %m %d %H")

# %%
# creating new dataframe loading the data parsing the year month daty hour and creating new columns using the above funcion
# in this if keep_date_col = False it removes the yeara month day hours this four features
new_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataSet/PRSA_Data_Dingling_20130301-20170228.csv', parse_dates=[['year','month', 'day', 'hour']], date_parser=convert_datetime, keep_date_col=True)
new_df
# Out:
#       year_month_day_hour     No  year month  ... RAIN   wd  WSPM   station
# 0     2013-03-01 00:00:00      1  2013     3  ...  0.0    E   0.5  Dingling
# 1     2013-03-01 01:00:00      2  2013     3  ...  0.0  ENE   0.7  Dingling
# 2     2013-03-01 02:00:00      3  2013     3  ...  0.0  ENE   0.2  Dingling
# 3     2013-03-01 03:00:00      4  2013     3  ...  0.0  NNE   1.0  Dingling
# 4     2013-03-01 04:00:00      5  2013     3  ...  0.0    N   2.1  Dingling
# ...                   ...    ...   ...   ...  ...  ...  ...   ...       ...
# 35059 2017-02-28 19:00:00  35060  2017     2  ...  0.0  NNE   1.3  Dingling
# 35060 2017-02-28 20:00:00  35061  2017     2  ...  0.0    N   2.1  Dingling
# 35061 2017-02-28 21:00:00  35062  2017     2  ...  0.0    N   1.5  Dingling
# 35062 2017-02-28 22:00:00  35063  2017     2  ...  0.0   NW   1.4  Dingling
# 35063 2017-02-28 23:00:00  35064  2017     2  ...  0.0    N   1.9  Dingling
#
# [35064 rows x 19 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_month_day_hour  35064 non-null  datetime64[ns]
#  1   No                   35064 non-null  int64
#  2   year                 35064 non-null  object
#  3   month                35064 non-null  object
#  4   day                  35064 non-null  object
#  5   hour                 35064 non-null  object
#  6   PM2.5                34285 non-null  float64
#  7   PM10                 34408 non-null  float64
#  8   SO2                  34334 non-null  float64
#  9   NO2                  33830 non-null  float64
#  10  CO                   33052 non-null  float64
#  11  O3                   33850 non-null  float64
#  12  TEMP                 35011 non-null  float64
#  13  PRES                 35014 non-null  float64
#  14  DEWP                 35011 non-null  float64
# ...

# %%
# we are going to analys month, so we convert month to numberic
new_df['month'] = pd.to_numeric(new_df['month'])

# %%
new_df.shape
# Out:
# (35064, 19)

# %%
new_df.isnull().any()
# Out:
# year_month_day_hour    False
# No                     False
# year                   False
# month                  False
# day                    False
# hour                   False
# PM2.5                   True
# PM10                    True
# SO2                     True
# NO2                     True
# CO                      True
# O3                      True
# TEMP                    True
# PRES                    True
# DEWP                    True
# RAIN                    True
# wd                      True
# WSPM                    True
# station                False
# dtype: bool

# %%
new_df.isnull().sum()
# Out:
# year_month_day_hour       0
# No                        0
# year                      0
# month                     0
# day                       0
# hour                      0
# PM2.5                   779
# PM10                    656
# SO2                     730
# NO2                    1234
# CO                     2012
# O3                     1214
# TEMP                     53
# PRES                     50
# DEWP                     53
# RAIN                     51
# wd                      140
# WSPM                     43
# station                   0
# dtype: int64

# %%
new_df.describe()
# Out:
#                  No         month  ...          RAIN          WSPM
# count  35064.000000  35064.000000  ...  35013.000000  35021.000000
# mean   17532.500000      6.522930  ...      0.060366      1.853836
# std    10122.249256      3.448752  ...      0.752899      1.309808
# min        1.000000      1.000000  ...      0.000000      0.000000
# 25%     8766.750000      4.000000  ...      0.000000      1.000000
# 50%    17532.500000      7.000000  ...      0.000000      1.500000
# 75%    26298.250000     10.000000  ...      0.000000      2.300000
# max    35064.000000     12.000000  ...     52.100000     10.000000
#
# [8 rows x 13 columns]

# %%
# Creating a copy of the dataframe
new_df_non_indexed = new_df.copy()

# %%
new_df = new_df.set_index('year_month_day_hour')

# %%
new_df.index
# Out:
# DatetimeIndex(['2013-03-01 00:00:00', '2013-03-01 01:00:00',
#                '2013-03-01 02:00:00', '2013-03-01 03:00:00',
#                '2013-03-01 04:00:00', '2013-03-01 05:00:00',
#                '2013-03-01 06:00:00', '2013-03-01 07:00:00',
#                '2013-03-01 08:00:00', '2013-03-01 09:00:00',
#                ...
#                '2017-02-28 14:00:00', '2017-02-28 15:00:00',
#                '2017-02-28 16:00:00', '2017-02-28 17:00:00',
#                '2017-02-28 18:00:00', '2017-02-28 19:00:00',
#                '2017-02-28 20:00:00', '2017-02-28 21:00:00',
#                '2017-02-28 22:00:00', '2017-02-28 23:00:00'],
#               dtype='datetime64[ns]', name='year_month_day_hour', length=35064, freq=None)

# %%
new_df.head()
# Out:
#                      No  year  month day hour  ...  DEWP  RAIN   wd  WSPM   station
# year_month_day_hour                            ...
# 2013-03-01 00:00:00   1  2013      3   1    0  ... -19.7   0.0    E   0.5  Dingling
# 2013-03-01 01:00:00   2  2013      3   1    1  ... -19.0   0.0  ENE   0.7  Dingling
# 2013-03-01 02:00:00   3  2013      3   1    2  ... -19.9   0.0  ENE   0.2  Dingling
# 2013-03-01 03:00:00   4  2013      3   1    3  ... -19.1   0.0  NNE   1.0  Dingling
# 2013-03-01 04:00:00   5  2013      3   1    4  ... -19.4   0.0    N   2.1  Dingling
#
# [5 rows x 18 columns]

# %%
new_df.loc['2013-03-01':'2013-03-05']
# Out:
#                       No  year  month day hour  ...  DEWP  RAIN   wd  WSPM   station
# year_month_day_hour                             ...
# 2013-03-01 00:00:00    1  2013      3   1    0  ... -19.7   0.0    E   0.5  Dingling
# 2013-03-01 01:00:00    2  2013      3   1    1  ... -19.0   0.0  ENE   0.7  Dingling
# 2013-03-01 02:00:00    3  2013      3   1    2  ... -19.9   0.0  ENE   0.2  Dingling
# 2013-03-01 03:00:00    4  2013      3   1    3  ... -19.1   0.0  NNE   1.0  Dingling
# 2013-03-01 04:00:00    5  2013      3   1    4  ... -19.4   0.0    N   2.1  Dingling
# ...                  ...   ...    ...  ..  ...  ...   ...   ...  ...   ...       ...
# 2013-03-05 19:00:00  116  2013      3   5   19  ...  -7.6   0.0  NNE   0.2  Dingling
# 2013-03-05 20:00:00  117  2013      3   5   20  ...  -7.3   0.0  NNE   0.7  Dingling
# 2013-03-05 21:00:00  118  2013      3   5   21  ...  -7.3   0.0  NNE   0.2  Dingling
# ...

# %%
new_df.loc['2013':'2015']
# Out:
#                         No  year  month day  ... RAIN   wd  WSPM   station
# year_month_day_hour                          ...
# 2013-03-01 00:00:00      1  2013      3   1  ...  0.0    E   0.5  Dingling
# 2013-03-01 01:00:00      2  2013      3   1  ...  0.0  ENE   0.7  Dingling
# 2013-03-01 02:00:00      3  2013      3   1  ...  0.0  ENE   0.2  Dingling
# 2013-03-01 03:00:00      4  2013      3   1  ...  0.0  NNE   1.0  Dingling
# 2013-03-01 04:00:00      5  2013      3   1  ...  0.0    N   2.1  Dingling
# ...                    ...   ...    ...  ..  ...  ...  ...   ...       ...
# 2015-12-31 19:00:00  24860  2015     12  31  ...  0.0   NE   0.6  Dingling
# 2015-12-31 20:00:00  24861  2015     12  31  ...  0.0   NW   1.1  Dingling
# 2015-12-31 21:00:00  24862  2015     12  31  ...  0.0   NE   0.9  Dingling
# 2015-12-31 22:00:00  24863  2015     12  31  ...  0.0  NNW   1.3  Dingling
# 2015-12-31 23:00:00  24864  2015     12  31  ...  0.0  NNW   1.3  Dingling
#
# ...

# %%
pm_data = new_df['PM2.5']
pm_data.head()
# Out:
# year_month_day_hour
# 2013-03-01 00:00:00    4.0
# 2013-03-01 01:00:00    7.0
# 2013-03-01 02:00:00    5.0
# 2013-03-01 03:00:00    6.0
# 2013-03-01 04:00:00    5.0
# Name: PM2.5, dtype: float64

# %%
pm_data.plot(grid=True)

# %%
# Taking 2015 data of PM2.5 and plotting
new_df_2015 = new_df.loc['2015']
pm_data_2015 = new_df_2015['PM2.5']
pm_data_2015.plot(grid=True)

# %%
# Taking 2016 data of PM2.5 and plotting
new_df_2015 = new_df.loc['2016']
pm_data_2015 = new_df_2015['PM2.5']
pm_data_2015.plot(grid=True)

# %%
import plotly.express as px

fig = px.line(new_df_non_indexed, x='year_month_day_hour', y='PM2.5', title='PM2.5 with Sliders')

fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(new_df_non_indexed, x='year_month_day_hour', y='PM2.5', title='PM2.5 with Sliders')

fig.update_xaxes(rangeslider_visible=True,
                 rangeselector=dict(buttons=list([
                                                  dict(count=1, label='1y', step='year', stepmode='backward'),
                                                  dict(count=1, label='2y', step='year', stepmode='backward'),
                                                  dict(count=1, label='3y', step='year', stepmode='backward'),
                                                  dict(step='all')
                 ])))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# we can visualize 1 year data above another year data, instead of doing separately, we can do one above another

df_2014 = new_df['2014'].reset_index()
df_2015 = new_df['2015'].reset_index()

df_2014['month_day_hour'] = df_2014.apply(lambda x: str(x['month'])+'-'+x['day'], axis=1)
df_2015['month_day_hour'] = df_2015.apply(lambda x: str(x['month'])+'-'+x['day'], axis=1)

plt.plot(df_2014['month_day_hour'], df_2014['PM2.5'])
plt.plot(df_2015['month_day_hour'], df_2015['PM2.5'])

plt.legend(['2014', '2015'])
plt.xlabel('Month')
plt.ylabel('PM2.5')
plt.title('Air quality plot for the year 2014 and 2015')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# Text(0.5, 1.0, 'Air quality plot for the year 2014 and 2015')

# %%
# univariate analysis
new_df['2014':'2016'][['month', 'PM2.5']].groupby('month').describe()
# Out:
#         PM2.5
#         count       mean         std  min   25%   50%     75%    max
# month
# 1      2173.0  70.285274   75.913587  3.0  12.0  38.0  113.00  443.0
# 2      1978.0  86.389282  105.603069  3.0  10.0  33.0  132.00  881.0
# 3      2212.0  80.193852   87.889440  3.0  13.0  47.0  123.25  474.0
# 4      2105.0  67.963325   56.430235  3.0  25.0  54.0   95.00  346.0
# 5      2188.0  47.994378   44.843130  3.0  16.0  35.0   67.00  358.0
# 6      2119.0  46.655403   43.877349  3.0  13.0  31.0   69.00  245.0
# 7      2205.0  61.671474   50.926149  3.0  21.0  48.0   91.00  252.0
# 8      2206.0  41.364869   37.279312  3.0  13.0  29.0   60.00  217.0
# 9      2074.0  45.356123   43.235331  3.0  11.0  27.0   78.00  240.0
# 10     2081.0  82.586257   92.234361  3.0  13.0  43.0  124.00  414.0
# 11     2141.0  77.500140   71.720648  3.0  20.0  56.0  112.00  394.0
# 12     2186.0  87.990851  104.677021  3.0  11.0  48.5  135.00  647.0

# %%
# Bivariate analysis
new_df['2014':'2016'][['month', 'PM2.5', 'TEMP']].groupby('month').agg({'PM2.5':['max'], 'TEMP':['min', 'max']})
# Out:
#        PM2.5  TEMP
#          max   min   max
# month
# 1      443.0 -16.6  12.4
# 2      881.0 -10.9  14.0
# 3      474.0  -6.4  26.0
# 4      346.0   1.3  32.0
# 5      358.0   7.0  41.4
# 6      245.0  15.1  38.1
# 7      252.0  16.8  39.2
# 8      217.0  16.6  36.3
# 9      240.0   7.8  34.5
# 10     414.0  -1.4  28.1
# 11     394.0 -10.3  20.8
# 12     647.0  -9.7  11.6

# %%
new_df_2015 = new_df['2015']
pm_data_2015 = new_df_2015[['PM2.5', 'TEMP']]
pm_data_2015.plot(subplots=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d46740b50>,
# ...
#       dtype=object)

# %%
new_df[['PM2.5', 'TEMP']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4605ffd0>,
# ...
#       dtype=object)

# %%
new_df['TEMP'].plot(kind='kde')

# %%
# lag plots
pd.plotting.lag_plot(new_df['TEMP'], lag=1)

# %%
pd.plotting.lag_plot(new_df['TEMP'], lag=10)

# %%
pd.plotting.lag_plot(new_df['TEMP'], lag=24)

# %%
pd.plotting.lag_plot(new_df['TEMP'], lag=8640) # there is some correlation with the previous years

# %%
pd.plotting.lag_plot(new_df['TEMP'], lag=4360) # negative correlation on previous 6 month level

# %%
pd.plotting.lag_plot(new_df['TEMP'], lag=2150) # There is no correlation with 3 month level

# %%
new_df_2015 = new_df['2015']
new_df_2015[['TEMP', 'PM2.5', 'PRES']].plot(subplots=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4146c5d0>,
# ...
#       dtype=object)

# %%
# Multivariate analysis
multi_data = new_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'PM2.5']]
multi_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d40e2fe50>,
# ...
#       dtype=object)

# %%
multi_data1 = new_df[['SO2', 'NO2', 'O3', 'CO', 'PM2.5']]
multi_data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d3f634690>,
# ...
#       dtype=object)

# %%
new_df['2014':'2016'][['PM2.5', 'O3']].plot(figsize=(15, 8), linewidth=3, fontsize=15)
plt.xlabel('year_month_day_hour', fontsize=20)
# Out:
# Text(0.5, 0, 'year_month_day_hour')

# %%
new_df_2015
# Out:
#                         No  year  month day  ... RAIN   wd  WSPM   station
# year_month_day_hour                          ...
# 2015-01-01 00:00:00  16105  2015      1   1  ...  0.0   NW   3.3  Dingling
# 2015-01-01 01:00:00  16106  2015      1   1  ...  0.0  NNE   1.2  Dingling
# 2015-01-01 02:00:00  16107  2015      1   1  ...  0.0  NNW   1.7  Dingling
# 2015-01-01 03:00:00  16108  2015      1   1  ...  0.0    N   1.7  Dingling
# 2015-01-01 04:00:00  16109  2015      1   1  ...  0.0   NE   1.8  Dingling
# ...                    ...   ...    ...  ..  ...  ...  ...   ...       ...
# 2015-12-31 19:00:00  24860  2015     12  31  ...  0.0   NE   0.6  Dingling
# 2015-12-31 20:00:00  24861  2015     12  31  ...  0.0   NW   1.1  Dingling
# 2015-12-31 21:00:00  24862  2015     12  31  ...  0.0   NE   0.9  Dingling
# 2015-12-31 22:00:00  24863  2015     12  31  ...  0.0  NNW   1.3  Dingling
# 2015-12-31 23:00:00  24864  2015     12  31  ...  0.0  NNW   1.3  Dingling
#
# ...

# %%
new_df.isnull().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
sns.pairplot(new_df[['SO2', 'NO2', 'O3', 'CO', 'PM2.5']])

# %%
new_corr = new_df[['SO2', 'NO2', 'O3', 'CO', 'PM2.5']].corr(method='pearson')
new_corr
# Out:
#             SO2       NO2        O3        CO     PM2.5
# SO2    1.000000  0.610433 -0.182096  0.529182  0.475117
# NO2    0.610433  1.000000 -0.373625  0.798753  0.718170
# O3    -0.182096 -0.373625  1.000000 -0.303275 -0.100542
# CO     0.529182  0.798753 -0.303275  1.000000  0.802737
# PM2.5  0.475117  0.718170 -0.100542  0.802737  1.000000

# %%
g = sns.heatmap(new_corr, vmax=6, center=0, square=True, linewidths=5, cbar_kws={'shrink':.5}, annot=True, fmt='.2f', cmap='coolwarm')
g.figure.set_size_inches(10, 10)
plt.show()

# %%
new_df.groupby('wd').agg(median=('PM2.5', 'median'), mean=('PM2.5', 'mean'), max=('PM2.5', 'max'), min=('PM2.5', 'min')).reset_index()
# Out:
#      wd  median       mean    max  min
# 0     E    70.0  88.623363  434.0  3.0
# 1   ENE    56.5  77.685514  647.0  3.0
# 2   ESE    78.5  96.492276  632.0  3.0
# 3     N    29.0  57.546221  536.0  3.0
# 4    NE    32.0  57.390083  530.0  3.0
# 5   NNE    26.0  53.946239  881.0  3.0
# 6   NNW    33.0  62.790775  548.0  3.0
# 7    NW    21.0  52.769116  535.0  3.0
# 8     S    52.0  72.497281  511.0  3.0
# 9    SE    70.0  85.045709  617.0  3.0
# 10  SSE    61.0  79.925967  614.0  3.0
# 11  SSW    50.0  73.078253  493.0  3.0
# 12   SW    46.0  70.233140  459.0  3.0
# 13    W    22.0  49.488104  446.0  3.0
# 14  WNW    14.0  37.307447  515.0  3.0
# 15  WSW    39.0  66.725926  451.0  3.0

# %%
new_df_na = new_df.copy()
new_df_na.dropna(axis=0, inplace=True)

# %%
pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['TEMP'])

# %%
new_df_na['TEMP'].resample('1m').mean()
# Out:
# year_month_day_hour
# 2013-03-31     6.039970
# 2013-04-30    12.208494
# 2013-05-31    21.886386
# 2013-06-30    23.752827
# 2013-07-31    27.405079
# 2013-08-31    27.228465
# 2013-09-30    20.482500
# 2013-10-31          NaN
# 2013-11-30     5.434524
# 2013-12-31     0.896623
# 2014-01-31     0.023428
# 2014-02-28    -0.352762
# 2014-03-31    10.415449
# 2014-04-30    17.235362
# 2014-05-31    22.043236
# 2014-06-30    25.194985
# 2014-07-31    28.409502
# 2014-08-31    26.284552
# 2014-09-30    20.834161
# 2014-10-31    13.556000
# 2014-11-30     6.357762
# 2014-12-31    -0.745582
# 2015-01-31    -0.590377
# 2015-02-28     1.572512
# 2015-03-31     8.707613
# 2015-04-30    15.566570
# 2015-05-31    21.300275
# 2015-06-30    24.636691
# 2015-07-31    26.228630
# 2015-08-31    26.135854
# 2015-09-30    20.392206
# 2015-10-31    14.387465
# 2015-11-30     3.358686
# 2015-12-31    -0.053912
# 2016-01-31    -4.233428
# 2016-02-29     1.434441
# 2016-03-31     8.687006
# ...

# %%
pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['TEMP'].resample('1m').mean())

# %%
pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['PM2.5'].resample('1m').mean())
